# %%
import tensorflow as tf
import os
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping
from matplotlib import pyplot as plt
from tensorflow.keras import models, layers
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %%
data = tf.keras.utils.image_dataset_from_directory('new/data')
# Out:
# Found 1500 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
data = data.map(lambda x, y: (x / 255, y))
data = data.map(lambda x, y: (tf.image.resize(x, (224, 224)), y))

# %%
train_size = int(len(data)*.8)
val_size = int(len(data)*.1)
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 37

# %%
val_size
# Out:
# 4

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
def augment_image(image, label):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.rot90(image, tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    return image, label

# %%
train = train.map(augment_image)

# %%
train
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\rebab\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

base_model.trainable = False

# Add custom classification layers
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation='sigmoid')(x)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# WARNING:tensorflow:From C:\Users\rebab\anaconda3\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
model.compile(optimizer='adam',
              loss=tf.losses.BinaryCrossentropy(),
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\rebab\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 112, 112, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 112, 112, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 112, 112, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 56, 56, 64)        576
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 56, 56, 64)        256
#  zation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormali  (None, 56, 56, 128)       512
#  zation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D  (None, 56, 56, 128)       1152
#  )
#
#  conv_dw_3_bn (BatchNormali  (None, 56, 56, 128)       512
#  zation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormali  (None, 56, 56, 128)       512
#  zation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D  (None, 28, 28, 128)       1152
#  )
#
#  conv_dw_4_bn (BatchNormali  (None, 28, 28, 128)       512
#  zation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormali  (None, 28, 28, 256)       1024
#  zation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D  (None, 28, 28, 256)       2304
#  )
#
#  conv_dw_5_bn (BatchNormali  (None, 28, 28, 256)       1024
#  zation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormali  (None, 28, 28, 256)       1024
#  zation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D  (None, 14, 14, 256)       2304
#  )
#
#  conv_dw_6_bn (BatchNormali  (None, 14, 14, 256)       1024
#  zation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D  (None, 14, 14, 512)       4608
#  )
#
#  conv_dw_7_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D  (None, 14, 14, 512)       4608
#  )
#
#  conv_dw_8_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D  (None, 14, 14, 512)       4608
#  )
#
#  conv_dw_9_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormali  (None, 14, 14, 512)       2048
#  zation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2  (None, 14, 14, 512)       4608
#  D)
#
#  conv_dw_10_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2  (None, 14, 14, 512)       4608
#  D)
#
#  conv_dw_11_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormal  (None, 14, 14, 512)       2048
#  ization)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D  (None, 15, 15, 512)       0
#  )
#
#  conv_dw_12 (DepthwiseConv2  (None, 7, 7, 512)         4608
#  D)
#
#  conv_dw_12_bn (BatchNormal  (None, 7, 7, 512)         2048
#  ization)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormal  (None, 7, 7, 1024)        4096
#  ization)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2  (None, 7, 7, 1024)        9216
#  D)
#
#  conv_dw_13_bn (BatchNormal  (None, 7, 7, 1024)        4096
#  ization)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormal  (None, 7, 7, 1024)        4096
#  ization)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 9651649 (36.82 MB)
# Trainable params: 6422785 (24.50 MB)
# Non-trainable params: 3228864 (12.32 MB)
# _________________________________________________________________

# %%
logdir='logs'

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=50, validation_data=val, callbacks=[tensorboard_callback, early_stopping])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\rebab\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\rebab\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 37/37 [==============================] - 99s 2s/step - loss: 1.9487 - accuracy: 0.8353 - val_loss: 0.2549 - val_accuracy: 0.9766
# Epoch 2/50
# 37/37 [==============================] - 85s 2s/step - loss: 0.2603 - accuracy: 0.9721 - val_loss: 0.2389 - val_accuracy: 0.9766
# Epoch 3/50
# 37/37 [==============================] - 85s 2s/step - loss: 0.2206 - accuracy: 0.9797 - val_loss: 0.1823 - val_accuracy: 0.9844
# Epoch 4/50
# 37/37 [==============================] - 85s 2s/step - loss: 0.2003 - accuracy: 0.9789 - val_loss: 0.2176 - val_accuracy: 0.9609
# Epoch 5/50
# 37/37 [==============================] - 74s 2s/step - loss: 0.1978 - accuracy: 0.9823 - val_loss: 0.2002 - val_accuracy: 0.9844
# Epoch 6/50
# 37/37 [==============================] - 76s 2s/step - loss: 0.1663 - accuracy: 0.9856 - val_loss: 0.1367 - val_accuracy: 1.0000
# Epoch 7/50
# 37/37 [==============================] - 83s 2s/step - loss: 0.1824 - accuracy: 0.9772 - val_loss: 0.1743 - val_accuracy: 0.9922
# Epoch 8/50
# 37/37 [==============================] - 77s 2s/step - loss: 0.1701 - accuracy: 0.9873 - val_loss: 0.1294 - val_accuracy: 1.0000
# Epoch 9/50
# 37/37 [==============================] - 82s 2s/step - loss: 0.1663 - accuracy: 0.9848 - val_loss: 0.1252 - val_accuracy: 1.0000
# Epoch 10/50
# 37/37 [==============================] - 78s 2s/step - loss: 0.1452 - accuracy: 0.9899 - val_loss: 0.1134 - val_accuracy: 1.0000
# Epoch 11/50
# 37/37 [==============================] - 79s 2s/step - loss: 0.1368 - accuracy: 0.9916 - val_loss: 0.1119 - val_accuracy: 1.0000
# Epoch 12/50
# 37/37 [==============================] - 78s 2s/step - loss: 0.1453 - accuracy: 0.9890 - val_loss: 0.1709 - val_accuracy: 0.9609
# Epoch 13/50
# 37/37 [==============================] - 123s 3s/step - loss: 0.1503 - accuracy: 0.9873 - val_loss: 0.1135 - val_accuracy: 1.0000
# Epoch 14/50
# 37/37 [==============================] - 121s 3s/step - loss: 0.1439 - accuracy: 0.9873 - val_loss: 0.1079 - val_accuracy: 1.0000
# Epoch 15/50
# 37/37 [==============================] - 122s 3s/step - loss: 0.1566 - accuracy: 0.9797 - val_loss: 0.1137 - val_accuracy: 1.0000
# Epoch 16/50
# 37/37 [==============================] - 127s 3s/step - loss: 0.1431 - accuracy: 0.9831 - val_loss: 0.1220 - val_accuracy: 0.9922
# Epoch 17/50
# 37/37 [==============================] - 111s 3s/step - loss: 0.1600 - accuracy: 0.9814 - val_loss: 0.1079 - val_accuracy: 1.0000
# Epoch 18/50
# 37/37 [==============================] - 120s 3s/step - loss: 0.1353 - accuracy: 0.9890 - val_loss: 0.1136 - val_accuracy: 0.9922
# Epoch 19/50
# 37/37 [==============================] - 110s 3s/step - loss: 0.1409 - accuracy: 0.9848 - val_loss: 0.1310 - val_accuracy: 0.9844
# Epoch 20/50
# 37/37 [==============================] - 106s 3s/step - loss: 0.1356 - accuracy: 0.9890 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 21/50
# 37/37 [==============================] - 107s 3s/step - loss: 0.1440 - accuracy: 0.9823 - val_loss: 0.1280 - val_accuracy: 0.9844
# Epoch 22/50
# 37/37 [==============================] - 107s 3s/step - loss: 0.1791 - accuracy: 0.9671 - val_loss: 0.1375 - val_accuracy: 0.9844
# Epoch 23/50
# 37/37 [==============================] - 109s 3s/step - loss: 0.1996 - accuracy: 0.9696 - val_loss: 0.1316 - val_accuracy: 0.9922
# Epoch 24/50
# 37/37 [==============================] - 98s 2s/step - loss: 0.1654 - accuracy: 0.9797 - val_loss: 0.1729 - val_accuracy: 0.9766
# Epoch 25/50
# 37/37 [==============================] - 81s 2s/step - loss: 0.1792 - accuracy: 0.9772 - val_loss: 0.1302 - val_accuracy: 0.9844
# Epoch 26/50
# 37/37 [==============================] - 75s 2s/step - loss: 0.1623 - accuracy: 0.9806 - val_loss: 0.1798 - val_accuracy: 0.9844
# Epoch 27/50
# 37/37 [==============================] - 73s 2s/step - loss: 0.1522 - accuracy: 0.9806 - val_loss: 0.1395 - val_accuracy: 0.9844
# Epoch 28/50
# 37/37 [==============================] - 76s 2s/step - loss: 0.1770 - accuracy: 0.9755 - val_loss: 0.1235 - val_accuracy: 0.9922
# Epoch 29/50
# 37/37 [==============================] - 79s 2s/step - loss: 0.1500 - accuracy: 0.9831 - val_loss: 0.1273 - val_accuracy: 0.9922
# Epoch 30/50
# 37/37 [==============================] - 72s 2s/step - loss: 0.1860 - accuracy: 0.9764 - val_loss: 0.1382 - val_accuracy: 0.9844

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
from sklearn.metrics import f1_score, confusion_matrix
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve, auc

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
true_labels = []
predicted_labels = []

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
    true_labels.extend(y)
    predicted_labels.extend(yhat)
# Out:
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 627ms/step

# %%
precision = pre.result().numpy()
recall = re.result().numpy()
accuracy = acc.result().numpy()
f1 = 2 * (precision * recall) / (precision + recall)

# %%
print("Precision:", precision)
print("Recall:", recall)
print("Accuracy:", accuracy)
print("F1 Score:", f1)
# Out:
# Precision: 0.98571426
# Recall: 1.0
# Accuracy: 0.9921875
# F1 Score: 0.9928057705120218

# %%
true_labels = np.array(true_labels)
predicted_labels = (np.array(predicted_labels) > 0.5).astype(int)

# %%
cm = confusion_matrix(predicted_labels, true_labels)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[58  0]
#  [ 1 69]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Adulterated', 'Pure'], yticklabels=['Adulterated', 'Pure'],
            annot_kws={"fontsize": 12})  # Increase the fontsize
plt.xlabel('True label')
plt.ylabel('Predicted label')
plt.title('Confusion Matrix')
plt.show()

# %%
report = classification_report(true_labels, predicted_labels, target_names=['Adulterated', 'Pure'], digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#  Adulterated     1.0000    0.9831    0.9915        59
#         Pure     0.9857    1.0000    0.9928        69
#
#     accuracy                         0.9922       128
#    macro avg     0.9929    0.9915    0.9921       128
# weighted avg     0.9923    0.9922    0.9922       128

# %%
precision, recall, _ = precision_recall_curve(true_labels, predicted_labels)
area_under_curve = auc(recall, precision)

print("Area Under Curve (AUC):", area_under_curve)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()
# Out:
# Area Under Curve (AUC): 0.9928571428571429

# %%
from sklearn.metrics import roc_curve
# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Compute ROC curve
fpr, tpr, _ = roc_curve(true_labels, predicted_labels)

# Plot ROC curve
ax.plot(fpr, tpr, marker='.')
ax.plot([0, 1], [0, 1], linestyle='--', color='red')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve')

# Show the plot
plt.show()
for i in range(len(fpr)):
    print(f"FPR: {fpr[i]}, TPR: {tpr[i]}")
# Out:
# FPR: 0.0, TPR: 0.0
# FPR: 0.01694915254237288, TPR: 1.0
# FPR: 1.0, TPR: 1.0

# %%
thresholds = np.arange(0, 1.01, 0.01)
predicted_labels = np.array(predicted_labels)
accuracies = [np.mean((predicted_labels.ravel().astype(bool) > threshold) == true_labels) for threshold in thresholds]
plt.plot(thresholds, accuracies, color='teal')
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Threshold')
plt.show()
for threshold, accuracy in zip(thresholds, accuracies):
    print(f'Threshold: {threshold:.2f}, Accuracy: {accuracy:.4f}')
# Out:
# Threshold: 0.00, Accuracy: 0.9922
# Threshold: 0.01, Accuracy: 0.9922
# Threshold: 0.02, Accuracy: 0.9922
# Threshold: 0.03, Accuracy: 0.9922
# Threshold: 0.04, Accuracy: 0.9922
# Threshold: 0.05, Accuracy: 0.9922
# Threshold: 0.06, Accuracy: 0.9922
# Threshold: 0.07, Accuracy: 0.9922
# Threshold: 0.08, Accuracy: 0.9922
# Threshold: 0.09, Accuracy: 0.9922
# Threshold: 0.10, Accuracy: 0.9922
# Threshold: 0.11, Accuracy: 0.9922
# Threshold: 0.12, Accuracy: 0.9922
# Threshold: 0.13, Accuracy: 0.9922
# Threshold: 0.14, Accuracy: 0.9922
# Threshold: 0.15, Accuracy: 0.9922
# Threshold: 0.16, Accuracy: 0.9922
# Threshold: 0.17, Accuracy: 0.9922
# Threshold: 0.18, Accuracy: 0.9922
# Threshold: 0.19, Accuracy: 0.9922
# Threshold: 0.20, Accuracy: 0.9922
# Threshold: 0.21, Accuracy: 0.9922
# Threshold: 0.22, Accuracy: 0.9922
# Threshold: 0.23, Accuracy: 0.9922
# Threshold: 0.24, Accuracy: 0.9922
# Threshold: 0.25, Accuracy: 0.9922
# Threshold: 0.26, Accuracy: 0.9922
# Threshold: 0.27, Accuracy: 0.9922
# Threshold: 0.28, Accuracy: 0.9922
# Threshold: 0.29, Accuracy: 0.9922
# Threshold: 0.30, Accuracy: 0.9922
# Threshold: 0.31, Accuracy: 0.9922
# Threshold: 0.32, Accuracy: 0.9922
# Threshold: 0.33, Accuracy: 0.9922
# Threshold: 0.34, Accuracy: 0.9922
# Threshold: 0.35, Accuracy: 0.9922
# Threshold: 0.36, Accuracy: 0.9922
# Threshold: 0.37, Accuracy: 0.9922
# Threshold: 0.38, Accuracy: 0.9922
# Threshold: 0.39, Accuracy: 0.9922
# Threshold: 0.40, Accuracy: 0.9922
# Threshold: 0.41, Accuracy: 0.9922
# Threshold: 0.42, Accuracy: 0.9922
# Threshold: 0.43, Accuracy: 0.9922
# Threshold: 0.44, Accuracy: 0.9922
# Threshold: 0.45, Accuracy: 0.9922
# Threshold: 0.46, Accuracy: 0.9922
# Threshold: 0.47, Accuracy: 0.9922
# Threshold: 0.48, Accuracy: 0.9922
# Threshold: 0.49, Accuracy: 0.9922
# Threshold: 0.50, Accuracy: 0.9922
# Threshold: 0.51, Accuracy: 0.9922
# Threshold: 0.52, Accuracy: 0.9922
# Threshold: 0.53, Accuracy: 0.9922
# Threshold: 0.54, Accuracy: 0.9922
# Threshold: 0.55, Accuracy: 0.9922
# Threshold: 0.56, Accuracy: 0.9922
# Threshold: 0.57, Accuracy: 0.9922
# Threshold: 0.58, Accuracy: 0.9922
# Threshold: 0.59, Accuracy: 0.9922
# Threshold: 0.60, Accuracy: 0.9922
# Threshold: 0.61, Accuracy: 0.9922
# Threshold: 0.62, Accuracy: 0.9922
# Threshold: 0.63, Accuracy: 0.9922
# Threshold: 0.64, Accuracy: 0.9922
# Threshold: 0.65, Accuracy: 0.9922
# Threshold: 0.66, Accuracy: 0.9922
# Threshold: 0.67, Accuracy: 0.9922
# Threshold: 0.68, Accuracy: 0.9922
# Threshold: 0.69, Accuracy: 0.9922
# Threshold: 0.70, Accuracy: 0.9922
# Threshold: 0.71, Accuracy: 0.9922
# Threshold: 0.72, Accuracy: 0.9922
# Threshold: 0.73, Accuracy: 0.9922
# Threshold: 0.74, Accuracy: 0.9922
# Threshold: 0.75, Accuracy: 0.9922
# Threshold: 0.76, Accuracy: 0.9922
# Threshold: 0.77, Accuracy: 0.9922
# Threshold: 0.78, Accuracy: 0.9922
# Threshold: 0.79, Accuracy: 0.9922
# Threshold: 0.80, Accuracy: 0.9922
# Threshold: 0.81, Accuracy: 0.9922
# Threshold: 0.82, Accuracy: 0.9922
# Threshold: 0.83, Accuracy: 0.9922
# Threshold: 0.84, Accuracy: 0.9922
# Threshold: 0.85, Accuracy: 0.9922
# Threshold: 0.86, Accuracy: 0.9922
# Threshold: 0.87, Accuracy: 0.9922
# Threshold: 0.88, Accuracy: 0.9922
# Threshold: 0.89, Accuracy: 0.9922
# Threshold: 0.90, Accuracy: 0.9922
# Threshold: 0.91, Accuracy: 0.9922
# Threshold: 0.92, Accuracy: 0.9922
# Threshold: 0.93, Accuracy: 0.9922
# Threshold: 0.94, Accuracy: 0.9922
# Threshold: 0.95, Accuracy: 0.9922
# Threshold: 0.96, Accuracy: 0.9922
# Threshold: 0.97, Accuracy: 0.9922
# Threshold: 0.98, Accuracy: 0.9922
# Threshold: 0.99, Accuracy: 0.9922
# Threshold: 1.00, Accuracy: 0.4609

# %%
plt.tight_layout()
plt.show()

# %%
import cv2

# %%
img = cv2.imread('new/Adulterated/A (8).jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
resize = tf.image.resize(img, (224,224))


# Predict the class probabilities
yhat = model.predict(np.expand_dims(resize/255, 0))
print(yhat)

# Get the predicted class and confidence level
threshold = 0.5
predicted_class = 'Pure' if yhat[0] > threshold else 'Adulterated'
confidence_level = (yhat[0][0] - 0.5) * 2 * 100 if yhat[0] > threshold else (0.5 - yhat[0][0]) * 2 * 100
print(f'Predicted class is {predicted_class} with confidence level {confidence_level:.2f}')

plt.imshow(resize.numpy().astype(int))
plt.show()
# Out:
# 1/1 [==============================] - 0s 58ms/step
# [[0.12902112]]
# Predicted class is Adulterated with confidence level 74.20

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('new\models','mobilenet.h5'))
# Out:
# C:\Users\rebab\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
loaded_model = load_model('new\models\mobilenet.h5')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
tflite_model = converter.convert()
with open('new\MobileNet.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\rebab\AppData\Local\Temp\tmpvm6n6yih\assets
# INFO:tensorflow:Assets written to: C:\Users\rebab\AppData\Local\Temp\tmpvm6n6yih\assets
